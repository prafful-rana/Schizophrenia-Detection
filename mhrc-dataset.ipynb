# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/fourier-decomposition-method/fdm.py
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-SCZ/586w1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-SCZ/S084-1W.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-SCZ/342mw1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-SCZ/r229w1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-SCZ/382w1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-SCZ/192w.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-SCZ/s083w1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-SCZ/573w1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-SCZ/387-02w1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-SCZ/s425w1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-SCZ/575w1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-SCZ/454-1W.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-SCZ/719w1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-SCZ/32w1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-SCZ/517w1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-SCZ/103w.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-SCZ/219w1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-SCZ/022w1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-SCZ/387-03w1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-SCZ/510-1W.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-SCZ/540w1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-SCZ/683w1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-SCZ/221w.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-SCZ/113w1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-SCZ/307w1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-SCZ/429w1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-SCZ/088w1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-SCZ/155w1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-SCZ/515w1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-SCZ/276w1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-SCZ/314w1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-SCZ/249w1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-SCZ/r416w1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-SCZ/401w1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-SCZ/642w1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-SCZ/156w1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-SCZ/423w.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-SCZ/s351w.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-SCZ/508w1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-SCZ/548w.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-SCZ/33w1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-SCZ/509w1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-SCZ/485w1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-SCZ/312w1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-SCZ/585w1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-Normal/S164W1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-Normal/s178w1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-Normal/s170w1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-Normal/S179W1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-Normal/s94w1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-Normal/S153W1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-Normal/S10W1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-Normal/S78W.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-Normal/S154W1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-Normal/s157w1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-Normal/S31W.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-Normal/s43w1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-Normal/s20w1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-Normal/S196W1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-Normal/S169W.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-Normal/S47W1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-Normal/S155W1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-Normal/s27w1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-Normal/S42W1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-Normal/s53w1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-Normal/s12w1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-Normal/s176w1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-Normal/S59LW.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-Normal/S174W1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-Normal/S182W1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-Normal/S163W1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-Normal/s158w1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-Normal/s152w1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-Normal/S50W.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-Normal/S55W1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-Normal/S18W1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-Normal/S165W1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-Normal/S60W.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-Normal/S85W1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-Normal/S167W1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-Normal/S26W1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-Normal/S72W1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-Normal/S177W1.eea
# /kaggle/input/mhrc-dataset-data/SCZ-Dataset2-Normal/s173w1.eea

# %% [markdown]
# There are two EEG data archives for two groups of subjects. The subjects were adolescents who had been screened by psychiatrist and devided into two groups: healthy (n = 39) and with symptoms of schizophrenia (n = 45).
#
# Each file contains an EEG record for one subject. Each TXT file contains a column with EEG samples from 16 EEG channels (electrode positions). Each number in the column is an EEG amplitude (mkV) at distinct sample. First 7680 samples represent 1st channel, then 7680 - 2nd channel, ets. The sampling rate is 128 Hz, thus 7680 samples refer to 1 minute of EEG record.

# %%
# !pip install kymatio
# !pip install livelossplot
# !pip install pyEDFlib
# !pip install mne
# !pip install pywt
# Out:
# Collecting kymatio
#   Downloading kymatio-0.3.0-py3-none-any.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.6/87.6 kB 929.1 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: appdirs in /opt/conda/lib/python3.10/site-packages (from kymatio) (1.4.4)
# Collecting configparser (from kymatio)
#   Obtaining dependency information for configparser from https://files.pythonhosted.org/packages/81/a3/0e5ed11da4b7770c15f6f319abf053f46b5a06c7d4273c48469b7899bd89/configparser-6.0.0-py3-none-any.whl.metadata
#   Downloading configparser-6.0.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from kymatio) (1.24.3)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from kymatio) (21.3)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from kymatio) (1.11.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->kymatio) (3.0.9)
# Downloading configparser-6.0.0-py3-none-any.whl (19 kB)
# Installing collected packages: configparser, kymatio
# Successfully installed configparser-6.0.0 kymatio-0.3.0
# Collecting livelossplot
#   Downloading livelossplot-0.5.5-py3-none-any.whl (22 kB)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from livelossplot) (3.7.4)
# Requirement already satisfied: bokeh in /opt/conda/lib/python3.10/site-packages (from livelossplot) (3.3.3)
# Requirement already satisfied: Jinja2>=2.9 in /opt/conda/lib/python3.10/site-packages (from bokeh->livelossplot) (3.1.2)
# Requirement already satisfied: contourpy>=1 in /opt/conda/lib/python3.10/site-packages (from bokeh->livelossplot) (1.1.0)
# Requirement already satisfied: numpy>=1.16 in /opt/conda/lib/python3.10/site-packages (from bokeh->livelossplot) (1.24.3)
# Requirement already satisfied: packaging>=16.8 in /opt/conda/lib/python3.10/site-packages (from bokeh->livelossplot) (21.3)
# Requirement already satisfied: pandas>=1.2 in /opt/conda/lib/python3.10/site-packages (from bokeh->livelossplot) (2.0.3)
# Requirement already satisfied: pillow>=7.1.0 in /opt/conda/lib/python3.10/site-packages (from bokeh->livelossplot) (9.5.0)
# Requirement already satisfied: PyYAML>=3.10 in /opt/conda/lib/python3.10/site-packages (from bokeh->livelossplot) (6.0.1)
# Requirement already satisfied: tornado>=5.1 in /opt/conda/lib/python3.10/site-packages (from bokeh->livelossplot) (6.3.3)
# Requirement already satisfied: xyzservices>=2021.09.1 in /opt/conda/lib/python3.10/site-packages (from bokeh->livelossplot) (2023.10.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->livelossplot) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->livelossplot) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->livelossplot) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->livelossplot) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->livelossplot) (2.8.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from Jinja2>=2.9->bokeh->livelossplot) (2.1.3)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.2->bokeh->livelossplot) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.2->bokeh->livelossplot) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->livelossplot) (1.16.0)
# Installing collected packages: livelossplot
# Successfully installed livelossplot-0.5.5
# Collecting pyEDFlib
#   Obtaining dependency information for pyEDFlib from https://files.pythonhosted.org/packages/d1/bc/ae0bb62a8f68c58b7c5ff1ea4a7ad1fd6649fcac06b5eba646e0aae9bf9d/pyEDFlib-0.1.36-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading pyEDFlib-0.1.36-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.9.1 in /opt/conda/lib/python3.10/site-packages (from pyEDFlib) (1.24.3)
# Downloading pyEDFlib-0.1.36-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 9.8 MB/s eta 0:00:00:00:010:01
# Installing collected packages: pyEDFlib
# Successfully installed pyEDFlib-0.1.36
# Requirement already satisfied: mne in /opt/conda/lib/python3.10/site-packages (1.6.0)
# Requirement already satisfied: numpy>=1.21.2 in /opt/conda/lib/python3.10/site-packages (from mne) (1.24.3)
# Requirement already satisfied: scipy>=1.7.1 in /opt/conda/lib/python3.10/site-packages (from mne) (1.11.4)
# Requirement already satisfied: matplotlib>=3.5.0 in /opt/conda/lib/python3.10/site-packages (from mne) (3.7.4)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from mne) (4.66.1)
# Requirement already satisfied: pooch>=1.5 in /opt/conda/lib/python3.10/site-packages (from mne) (1.8.0)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.10/site-packages (from mne) (5.1.1)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from mne) (21.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from mne) (3.1.2)
# Requirement already satisfied: lazy-loader>=0.3 in /opt/conda/lib/python3.10/site-packages (from mne) (0.3)
# Requirement already satisfied: defusedxml in /opt/conda/lib/python3.10/site-packages (from mne) (0.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.5.0->mne) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.5.0->mne) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.5.0->mne) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.5.0->mne) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.5.0->mne) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.5.0->mne) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.5.0->mne) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /opt/conda/lib/python3.10/site-packages (from pooch>=1.5->mne) (4.1.0)
# Requirement already satisfied: requests>=2.19.0 in /opt/conda/lib/python3.10/site-packages (from pooch>=1.5->mne) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->mne) (2.1.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.5.0->mne) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.5->mne) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.5->mne) (2023.11.17)
# ERROR: Could not find a version that satisfies the requirement pywt (from versions: none)
# ERROR: No matching distribution found for pywt

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Flatten, Dense
from kymatio.keras import Scattering2D
from sklearn.model_selection import train_test_split
import os
import cv2
import numpy as np
import mne
import glob
import matplotlib.pyplot as plt
from scipy.signal import hilbert
import math
from scipy.signal import unit_impulse as imp
from scipy.fft import fft
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
sample = 7680
sf = 128 #Hz
sec = 4
num_channels = 16
phases = [math.pi/4,math.pi/8,math.pi/16,math.pi/32]

# %%
def read():
    path = '/kaggle/input/mhrc-dataset-data/'
    folders = ['SCZ-Dataset2-Normal/','SCZ-Dataset2-SCZ/']
    observations = []
    labels = []
    for idx,folder in enumerate(folders):
        files = glob.glob(path + folder + '*.eea')
        for filename in files:
            data = []
            labels.append(idx)
            with open(filename,'r') as file:
                contents = file.read()
                contents = contents.split(' \n')
                contents = [float(i) for i in contents[:-1]]
                for i in range(1,num_channels+1):
                    data.append(np.array(contents[(i-1)*sample : i*sample]))
                data = np.array(data)
                data.shape
            observations.append(data)
    observations = np.array(observations)
    labels = np.array(labels)
    return observations,labels

# %%
s,labels = read()

# %%
s.shape
# Out:
# (84, 16, 7680)

# %%
def divide(x):
    data = []
    jmp = sf*sec
    for curr in x:
        for i in range(0,sample,jmp):
            data.append(curr[:,i:i+jmp])
    return np.array(data)

# %%
container = divide(s)

# %%
labels = [0]*(int(60/sec)*39*len(phases)) + [1]*(45*int(60/sec)*len(phases))
labels = np.array(labels)

# %%
container.shape,labels.shape
# Out:
# ((1260, 16, 512), (5040,))

# %%
def phase_shift(samples,alpha):
    shifted = []
    for val in alpha:
        curr = []
        for data in samples:
            transformed = hilbert(data)
            temp = data*math.cos(val) + transformed*math.sin(val)
            curr.append(np.array(temp.real))
        shifted.append(curr)
    return np.array(shifted)

# %%
def augment_data(container):
    ret = []
    for sample in container:
        curr = phase_shift(sample,phases)
        ret.append(curr)
    return np.array(ret)
temp = augment_data(container)

# %%
container = temp.reshape(temp.shape[0]*temp.shape[1],temp.shape[2],temp.shape[3])

# %%
import sys
sys.path.insert(1,'/kaggle/input/fourier-decomposition-method')
from fdm import fdm

# %%
plt.plot(container[123,0]), labels[123]
# Out:
# ([<matplotlib.lines.Line2D at 0x78a974f30910>], 0)

# %%
data = []
for i in range(container.shape[0]):
    gamma,beta,alpha,theta,delta = [],[],[],[],[]
    for j in range(num_channels):
        curr = fdm(container[i,j,:].reshape(sf*sec,1), fs = sf , fc = np.array([4,8,12,35]), data_type='columns',plot_subbands= False)
        gamma.append(curr[:,0])
        beta.append(curr[:,1])
        alpha.append(curr[:,2])
        theta.append(curr[:,3])
        delta.append(curr[:,4])
    data.append(np.array([gamma,beta,alpha,theta,delta]))
data = np.array(data)

# %%
labels.shape
# Out:
# (5040,)

# %%
x_train,x_test,y_train,y_test = train_test_split(np.array(data),np.array(labels),test_size=0.2,random_state=42)
y_train = y_train.astype('double')
y_test = y_test.astype('double')

print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")
# x_train, x_test = x_train / 255., x_test / 255.
# Out:
# x_train shape: (4032, 5, 16, 512) - y_train shape: (4032,)
# x_test shape: (1008, 5, 16, 512) - y_test shape: (1008,)

# %%
from keras import layers , models
import keras    
from keras import regularizers
def DenseNet(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.relu,kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4),bias_regularizer=regularizers.L2(1e-4),activity_regularizer=regularizers.L2(1e-5))(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super().__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        #Creates a sequence of numbers that begins at start and extends by increments of delta up to but not including limit.
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded

def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Attention and Normalization
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(inputs, inputs)
    x = layers.Dropout(dropout)(x)
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    res = x + inputs

    # Feed Forward Part
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(res)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    return x + res

# %%
def build_model(head_size=256,num_heads=4,ff_dim=4,num_transformer_blocks=4,mlp_units=[128],mlp_dropout=0.4,dropout=0.25):
    inputs = layers.Input(shape=(5,num_channels,sf*sec))
    
    # encoded_patches = PatchEncoder(25, 128)(patches)
    x = None
    y1 = Scattering2D(J=2, L=4)(inputs[:,0,:,:])
    y1 = PatchEncoder(y1.shape[1], 128)(tf.reshape(y1,[-1,y1.shape[1],y1.shape[2]*y1.shape[3]]))
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(y1, head_size, num_heads, ff_dim, dropout)
    representation1 = layers.LayerNormalization(epsilon=1e-6)(x)
    representation1 = layers.Flatten()(representation1)
    features1 = DenseNet(representation1, hidden_units=[1024,128], dropout_rate=0.5)

    y2 = Scattering2D(J=2, L=4)(inputs[:,1,:,:])
    y2 = PatchEncoder(y2.shape[1], 128)(tf.reshape(y2,[-1,y2.shape[1],y2.shape[2]*y2.shape[3]]))
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(y2, head_size, num_heads, ff_dim, dropout)
    representation2 = layers.LayerNormalization(epsilon=1e-6)(x)
    representation2 = layers.Flatten()(representation2)
    features2 = DenseNet(representation2, hidden_units=[1024,128], dropout_rate=0.5)

    y3 = Scattering2D(J=2, L=4)(inputs[:,2,:,:])
    y3 = PatchEncoder(y3.shape[1], 128)(tf.reshape(y3,[-1,y3.shape[1],y3.shape[2]*y3.shape[3]]))
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(y3, head_size, num_heads, ff_dim, dropout)
    representation3 = layers.LayerNormalization(epsilon=1e-6)(x)
    representation3 = layers.Flatten()(representation3)
    features3 = DenseNet(representation3, hidden_units=[1024,128], dropout_rate=0.5)

    y4 = Scattering2D(J=2, L=4)(inputs[:,3,:,:])
    y4 = PatchEncoder(y4.shape[1], 128)(tf.reshape(y4,[-1,y4.shape[1],y4.shape[2]*y4.shape[3]]))
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(y4, head_size, num_heads, ff_dim, dropout)
    representation4 = layers.LayerNormalization(epsilon=1e-6)(x)
    representation4 = layers.Flatten()(representation4)
    features4 = DenseNet(representation4, hidden_units=[1024,128], dropout_rate=0.5)

    y5 = Scattering2D(J=2, L=4)(inputs[:,4,:,:])
    y5 = PatchEncoder(y5.shape[1], 128)(tf.reshape(y5,[-1,y5.shape[1],y5.shape[2]*y5.shape[3]]))
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(y5, head_size, num_heads, ff_dim, dropout)
    representation5 = layers.LayerNormalization(epsilon=1e-6)(x)
    representation5 = layers.Flatten()(representation5)
    features5 = DenseNet(representation5, hidden_units=[1024,128], dropout_rate=0.5)

    features = tf.concat([features1,features2,features3,features4,features5],axis=1)
    # features5 = DenseNet(features, hidden_units=[128,64], dropout_rate=0)
    logits = layers.Dense(1, activation = 'sigmoid')(features)
   
    model = keras.Model(inputs=inputs, outputs=logits)
    return model

# %%
model = build_model(
    head_size=256,
    num_heads=4,
    ff_dim=4,
    num_transformer_blocks=4,
    mlp_units=[128],
    mlp_dropout=0.4,
    dropout=0.25,
)

model.compile(
    loss="binary_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=1e-4),
    metrics=["binary_accuracy"],
)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 5, 16, 512)]         0         []
#
#  tf.__operators__.getitem (  (None, 16, 512)              0         ['input_1[0][0]']
#  SlicingOpLambda)
#
#  tf.__operators__.getitem_1  (None, 16, 512)              0         ['input_1[0][0]']
#   (SlicingOpLambda)
#
#  tf.__operators__.getitem_2  (None, 16, 512)              0         ['input_1[0][0]']
#   (SlicingOpLambda)
#
#  tf.__operators__.getitem_3  (None, 16, 512)              0         ['input_1[0][0]']
#   (SlicingOpLambda)
#
#  tf.__operators__.getitem_4  (None, 16, 512)              0         ['input_1[0][0]']
#   (SlicingOpLambda)
#
#  scattering2d (Scattering2D  (None, 25, 4, 128)           0         ['tf.__operators__.getitem[0][
#  )                                                                  0]']
#
#  scattering2d_1 (Scattering  (None, 25, 4, 128)           0         ['tf.__operators__.getitem_1[0
#  2D)                                                                ][0]']
#
#  scattering2d_2 (Scattering  (None, 25, 4, 128)           0         ['tf.__operators__.getitem_2[0
#  2D)                                                                ][0]']
#
#  scattering2d_3 (Scattering  (None, 25, 4, 128)           0         ['tf.__operators__.getitem_3[0
#  2D)                                                                ][0]']
#
#  scattering2d_4 (Scattering  (None, 25, 4, 128)           0         ['tf.__operators__.getitem_4[0
#  2D)                                                                ][0]']
#
#  tf.reshape (TFOpLambda)     (None, 25, 512)              0         ['scattering2d[0][0]']
#
#  tf.reshape_1 (TFOpLambda)   (None, 25, 512)              0         ['scattering2d_1[0][0]']
#
#  tf.reshape_2 (TFOpLambda)   (None, 25, 512)              0         ['scattering2d_2[0][0]']
#
#  tf.reshape_3 (TFOpLambda)   (None, 25, 512)              0         ['scattering2d_3[0][0]']
#
#  tf.reshape_4 (TFOpLambda)   (None, 25, 512)              0         ['scattering2d_4[0][0]']
#
#  patch_encoder (PatchEncode  (None, 25, 128)              68864     ['tf.reshape[0][0]']
#  r)
#
#  patch_encoder_1 (PatchEnco  (None, 25, 128)              68864     ['tf.reshape_1[0][0]']
#  der)
#
#  patch_encoder_2 (PatchEnco  (None, 25, 128)              68864     ['tf.reshape_2[0][0]']
#  der)
#
#  patch_encoder_3 (PatchEnco  (None, 25, 128)              68864     ['tf.reshape_3[0][0]']
#  der)
#
#  patch_encoder_4 (PatchEnco  (None, 25, 128)              68864     ['tf.reshape_4[0][0]']
#  der)
#
#  multi_head_attention_3 (Mu  (None, 25, 128)              527488    ['patch_encoder[0][0]',
#  ltiHeadAttention)                                                   'patch_encoder[0][0]']
#
#  multi_head_attention_7 (Mu  (None, 25, 128)              527488    ['patch_encoder_1[0][0]',
#  ltiHeadAttention)                                                   'patch_encoder_1[0][0]']
#
#  multi_head_attention_11 (M  (None, 25, 128)              527488    ['patch_encoder_2[0][0]',
#  ultiHeadAttention)                                                  'patch_encoder_2[0][0]']
#
#  multi_head_attention_15 (M  (None, 25, 128)              527488    ['patch_encoder_3[0][0]',
#  ultiHeadAttention)                                                  'patch_encoder_3[0][0]']
#
#  multi_head_attention_19 (M  (None, 25, 128)              527488    ['patch_encoder_4[0][0]',
#  ultiHeadAttention)                                                  'patch_encoder_4[0][0]']
#
#  dropout_6 (Dropout)         (None, 25, 128)              0         ['multi_head_attention_3[0][0]
#                                                                     ']
#
#  dropout_16 (Dropout)        (None, 25, 128)              0         ['multi_head_attention_7[0][0]
#                                                                     ']
#
#  dropout_26 (Dropout)        (None, 25, 128)              0         ['multi_head_attention_11[0][0
#                                                                     ]']
#
#  dropout_36 (Dropout)        (None, 25, 128)              0         ['multi_head_attention_15[0][0
#                                                                     ]']
#
#  dropout_46 (Dropout)        (None, 25, 128)              0         ['multi_head_attention_19[0][0
#                                                                     ]']
#
#  layer_normalization_6 (Lay  (None, 25, 128)              256       ['dropout_6[0][0]']
#  erNormalization)
#
#  layer_normalization_15 (La  (None, 25, 128)              256       ['dropout_16[0][0]']
#  yerNormalization)
#
#  layer_normalization_24 (La  (None, 25, 128)              256       ['dropout_26[0][0]']
#  yerNormalization)
#
#  layer_normalization_33 (La  (None, 25, 128)              256       ['dropout_36[0][0]']
#  yerNormalization)
#
#  layer_normalization_42 (La  (None, 25, 128)              256       ['dropout_46[0][0]']
#  yerNormalization)
#
#  tf.__operators__.add_6 (TF  (None, 25, 128)              0         ['layer_normalization_6[0][0]'
#  OpLambda)                                                          , 'patch_encoder[0][0]']
#
#  tf.__operators__.add_14 (T  (None, 25, 128)              0         ['layer_normalization_15[0][0]
#  FOpLambda)                                                         ',
#                                                                      'patch_encoder_1[0][0]']
#
#  tf.__operators__.add_22 (T  (None, 25, 128)              0         ['layer_normalization_24[0][0]
#  FOpLambda)                                                         ',
#                                                                      'patch_encoder_2[0][0]']
#
#  tf.__operators__.add_30 (T  (None, 25, 128)              0         ['layer_normalization_33[0][0]
#  FOpLambda)                                                         ',
#                                                                      'patch_encoder_3[0][0]']
#
#  tf.__operators__.add_38 (T  (None, 25, 128)              0         ['layer_normalization_42[0][0]
#  FOpLambda)                                                         ',
#                                                                      'patch_encoder_4[0][0]']
#
#  conv1d_6 (Conv1D)           (None, 25, 4)                516       ['tf.__operators__.add_6[0][0]
#                                                                     ']
#
#  conv1d_14 (Conv1D)          (None, 25, 4)                516       ['tf.__operators__.add_14[0][0
#                                                                     ]']
#
#  conv1d_22 (Conv1D)          (None, 25, 4)                516       ['tf.__operators__.add_22[0][0
#                                                                     ]']
#
#  conv1d_30 (Conv1D)          (None, 25, 4)                516       ['tf.__operators__.add_30[0][0
#                                                                     ]']
#
#  conv1d_38 (Conv1D)          (None, 25, 4)                516       ['tf.__operators__.add_38[0][0
#                                                                     ]']
#
#  dropout_7 (Dropout)         (None, 25, 4)                0         ['conv1d_6[0][0]']
#
#  dropout_17 (Dropout)        (None, 25, 4)                0         ['conv1d_14[0][0]']
#
#  dropout_27 (Dropout)        (None, 25, 4)                0         ['conv1d_22[0][0]']
#
#  dropout_37 (Dropout)        (None, 25, 4)                0         ['conv1d_30[0][0]']
#
#  dropout_47 (Dropout)        (None, 25, 4)                0         ['conv1d_38[0][0]']
#
#  conv1d_7 (Conv1D)           (None, 25, 128)              640       ['dropout_7[0][0]']
#
#  conv1d_15 (Conv1D)          (None, 25, 128)              640       ['dropout_17[0][0]']
#
#  conv1d_23 (Conv1D)          (None, 25, 128)              640       ['dropout_27[0][0]']
#
#  conv1d_31 (Conv1D)          (None, 25, 128)              640       ['dropout_37[0][0]']
#
#  conv1d_39 (Conv1D)          (None, 25, 128)              640       ['dropout_47[0][0]']
#
#  layer_normalization_7 (Lay  (None, 25, 128)              256       ['conv1d_7[0][0]']
#  erNormalization)
#
#  layer_normalization_16 (La  (None, 25, 128)              256       ['conv1d_15[0][0]']
#  yerNormalization)
#
#  layer_normalization_25 (La  (None, 25, 128)              256       ['conv1d_23[0][0]']
#  yerNormalization)
#
#  layer_normalization_34 (La  (None, 25, 128)              256       ['conv1d_31[0][0]']
#  yerNormalization)
#
#  layer_normalization_43 (La  (None, 25, 128)              256       ['conv1d_39[0][0]']
#  yerNormalization)
#
#  tf.__operators__.add_7 (TF  (None, 25, 128)              0         ['layer_normalization_7[0][0]'
#  OpLambda)                                                          , 'tf.__operators__.add_6[0][0
#                                                                     ]']
#
#  tf.__operators__.add_15 (T  (None, 25, 128)              0         ['layer_normalization_16[0][0]
#  FOpLambda)                                                         ',
#                                                                      'tf.__operators__.add_14[0][0
#                                                                     ]']
#
#  tf.__operators__.add_23 (T  (None, 25, 128)              0         ['layer_normalization_25[0][0]
#  FOpLambda)                                                         ',
#                                                                      'tf.__operators__.add_22[0][0
#                                                                     ]']
#
#  tf.__operators__.add_31 (T  (None, 25, 128)              0         ['layer_normalization_34[0][0]
#  FOpLambda)                                                         ',
#                                                                      'tf.__operators__.add_30[0][0
#                                                                     ]']
#
#  tf.__operators__.add_39 (T  (None, 25, 128)              0         ['layer_normalization_43[0][0]
#  FOpLambda)                                                         ',
#                                                                      'tf.__operators__.add_38[0][0
#                                                                     ]']
#
#  layer_normalization_8 (Lay  (None, 25, 128)              256       ['tf.__operators__.add_7[0][0]
#  erNormalization)                                                   ']
#
#  layer_normalization_17 (La  (None, 25, 128)              256       ['tf.__operators__.add_15[0][0
#  yerNormalization)                                                  ]']
#
#  layer_normalization_26 (La  (None, 25, 128)              256       ['tf.__operators__.add_23[0][0
#  yerNormalization)                                                  ]']
#
#  layer_normalization_35 (La  (None, 25, 128)              256       ['tf.__operators__.add_31[0][0
#  yerNormalization)                                                  ]']
#
#  layer_normalization_44 (La  (None, 25, 128)              256       ['tf.__operators__.add_39[0][0
#  yerNormalization)                                                  ]']
#
#  flatten (Flatten)           (None, 3200)                 0         ['layer_normalization_8[0][0]'
#                                                                     ]
#
#  flatten_1 (Flatten)         (None, 3200)                 0         ['layer_normalization_17[0][0]
#                                                                     ']
#
#  flatten_2 (Flatten)         (None, 3200)                 0         ['layer_normalization_26[0][0]
#                                                                     ']
#
#  flatten_3 (Flatten)         (None, 3200)                 0         ['layer_normalization_35[0][0]
#                                                                     ']
#
#  flatten_4 (Flatten)         (None, 3200)                 0         ['layer_normalization_44[0][0]
#                                                                     ']
#
#  dense_1 (Dense)             (None, 1024)                 3277824   ['flatten[0][0]']
#
#  dense_4 (Dense)             (None, 1024)                 3277824   ['flatten_1[0][0]']
#
#  dense_7 (Dense)             (None, 1024)                 3277824   ['flatten_2[0][0]']
#
#  dense_10 (Dense)            (None, 1024)                 3277824   ['flatten_3[0][0]']
#
#  dense_13 (Dense)            (None, 1024)                 3277824   ['flatten_4[0][0]']
#
#  dropout_8 (Dropout)         (None, 1024)                 0         ['dense_1[0][0]']
#
#  dropout_18 (Dropout)        (None, 1024)                 0         ['dense_4[0][0]']
#
#  dropout_28 (Dropout)        (None, 1024)                 0         ['dense_7[0][0]']
#
#  dropout_38 (Dropout)        (None, 1024)                 0         ['dense_10[0][0]']
#
#  dropout_48 (Dropout)        (None, 1024)                 0         ['dense_13[0][0]']
#
#  dense_2 (Dense)             (None, 128)                  131200    ['dropout_8[0][0]']
#
#  dense_5 (Dense)             (None, 128)                  131200    ['dropout_18[0][0]']
#
#  dense_8 (Dense)             (None, 128)                  131200    ['dropout_28[0][0]']
#
#  dense_11 (Dense)            (None, 128)                  131200    ['dropout_38[0][0]']
#
#  dense_14 (Dense)            (None, 128)                  131200    ['dropout_48[0][0]']
#
#  dropout_9 (Dropout)         (None, 128)                  0         ['dense_2[0][0]']
#
#  dropout_19 (Dropout)        (None, 128)                  0         ['dense_5[0][0]']
#
#  dropout_29 (Dropout)        (None, 128)                  0         ['dense_8[0][0]']
#
#  dropout_39 (Dropout)        (None, 128)                  0         ['dense_11[0][0]']
#
#  dropout_49 (Dropout)        (None, 128)                  0         ['dense_14[0][0]']
#
#  tf.concat (TFOpLambda)      (None, 640)                  0         ['dropout_9[0][0]',
#                                                                      'dropout_19[0][0]',
#                                                                      'dropout_29[0][0]',
#                                                                      'dropout_39[0][0]',
#                                                                      'dropout_49[0][0]']
#
#  dense_15 (Dense)            (None, 1)                    641       ['tf.concat[0][0]']
#
# ==================================================================================================
# Total params: 20037141 (76.44 MB)
# Trainable params: 20037141 (76.44 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
# !pip install livelossplot
# Out:
# Requirement already satisfied: livelossplot in /opt/conda/lib/python3.10/site-packages (0.5.5)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from livelossplot) (3.7.4)
# Requirement already satisfied: bokeh in /opt/conda/lib/python3.10/site-packages (from livelossplot) (3.3.3)
# Requirement already satisfied: Jinja2>=2.9 in /opt/conda/lib/python3.10/site-packages (from bokeh->livelossplot) (3.1.2)
# Requirement already satisfied: contourpy>=1 in /opt/conda/lib/python3.10/site-packages (from bokeh->livelossplot) (1.1.0)
# Requirement already satisfied: numpy>=1.16 in /opt/conda/lib/python3.10/site-packages (from bokeh->livelossplot) (1.24.3)
# Requirement already satisfied: packaging>=16.8 in /opt/conda/lib/python3.10/site-packages (from bokeh->livelossplot) (21.3)
# Requirement already satisfied: pandas>=1.2 in /opt/conda/lib/python3.10/site-packages (from bokeh->livelossplot) (2.0.3)
# Requirement already satisfied: pillow>=7.1.0 in /opt/conda/lib/python3.10/site-packages (from bokeh->livelossplot) (9.5.0)
# Requirement already satisfied: PyYAML>=3.10 in /opt/conda/lib/python3.10/site-packages (from bokeh->livelossplot) (6.0.1)
# Requirement already satisfied: tornado>=5.1 in /opt/conda/lib/python3.10/site-packages (from bokeh->livelossplot) (6.3.3)
# Requirement already satisfied: xyzservices>=2021.09.1 in /opt/conda/lib/python3.10/site-packages (from bokeh->livelossplot) (2023.10.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->livelossplot) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->livelossplot) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->livelossplot) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->livelossplot) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->livelossplot) (2.8.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from Jinja2>=2.9->bokeh->livelossplot) (2.1.3)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.2->bokeh->livelossplot) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.2->bokeh->livelossplot) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->livelossplot) (1.16.0)

# %%
from livelossplot import PlotLossesKeras
callbacks = [keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True),PlotLossesKeras()]

history = model.fit(
    x_train,
    y_train,
    epochs=150,
    batch_size=8,
    callbacks=callbacks,
    validation_data=(x_test,y_test)
)
# Out:
# binary_accuracy
# 	training         	 (min:    0.634, max:    1.000, cur:    0.982)
# 	validation       	 (min:    0.677, max:    1.000, cur:    0.989)
# Loss
# 	training         	 (min:    0.072, max:    4.755, cur:    0.183)
# 	validation       	 (min:    0.074, max:    4.271, cur:    0.129)
# 504/504 [==============================] - 30s 60ms/step - loss: 0.1835 - binary_accuracy: 0.9824 - val_loss: 0.1291 - val_binary_accuracy: 0.9891

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(history.history['binary_accuracy'])
plt.plot(history.history['val_binary_accuracy'])
plt.legend(['accuracy','val_accuracy'])
plt.title('Accuracy Plot')
plt.subplot(1,2,2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['loss','val_loss'])
plt.title('Loss Plot')
# Out:
# Text(0.5, 1.0, 'Loss Plot')

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

cm = confusion_matrix(y_test, model.predict(x_test).round())
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 32/32 [==============================] - 10s 52ms/step

# %%
precision = (cm[1][1]/(cm[1][1]+cm[0][1]))*100
print(f'Precision = {precision}%')

recall = (cm[1][1]/(cm[1][1]+cm[1][0]))*100
print(f'Recall = {recall}%')

f1_score = (2*precision*recall)/(precision+recall)
print(f'F1 Score = {f1_score}%')
# Out:
# Precision = 99.80544747081711%
# Recall = 100.0%
# F1 Score = 99.90262901655306%

# %%
import tsgm

# %%
def augment(container):
    aug_model = tsgm.models.augmentations.GaussianNoise(0.2)
    for sample in container:
        for channel in sample:
            samples = aug_model.generate(X=channel, n_samples=10)
            print(samples.shape)
            break
augment(container[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[35], line 7
#       5         print(samples.shape)
#       6         break
# ----> 7 augment(container[0])
#
# Cell In[35], line 4, in augment(container)
#       2 aug_model = tsgm.models.augmentations.GaussianNoise(0.2)
#       3 for sample in container:
# ----> 4     samples = aug_model.generate(X=sample, n_samples=10)
#       5     print(samples.shape)
#       6     break
#
# File /opt/conda/lib/python3.10/site-packages/tsgm/models/augmentations.py:102, in GaussianNoise.generate(self, X, y, n_samples, mean, variance)
#      99 has_labels = y is not None
#     100 if self.per_channel:
#     101     gauss = np.random.normal(
# --> 102         mean, sigma, (n_samples, X.shape[1], X.shape[2])
#     103     )
#     104 else:
#     105     gauss = np.random.normal(mean, sigma, (n_samples, X.shape[1]))
#
# IndexError: tuple index out of range

# %%
# Out:
# (1260, 16, 512)
